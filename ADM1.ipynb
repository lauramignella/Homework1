# %%
#INTRODUCTION

# %%
if __name__ == '__main__':
    print("Hello, World!")

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n % 2==1:
        print('Weird')
    else:
        if 2<=n<=5:
           print('Not Weird')
        elif 6<=n<=20:
           print('Weird')
        else:
           print('Not Weird')

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(0,n):
      print(i*i)

# %%
def is_leap(year):
    leap = False
    
    # Write your logic here
    
    if year%4==0:
        if year%100==0:
            if year%400==0:
               leap=True
            else:
                leap=False
        else:
            leap=True
    else:
        leap=False
            
            
    return leap

year = int(input())
print(is_leap(year))

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(1,n+1):
        print(i, end='')

# %%
#BASIC DATA TYPES

# %%
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    list1=[[i,j,k] for i in range(x+1) for j in range(y+1) for k in range(z+1) if i+j+k != n]
    print(list1)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())

    score=list(arr)
    s=max(score)
    score.remove(s)
    
    for x in score:
      if max(score)==s:
        score.remove(max(score))

    if max(score)!=s:
       print(max(score))
    else:
      score=[]
      print(x in score)

# %%
if __name__ == '__main__':
    students=[]
    scores=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        student=[name, score]
        students.append(student)
        scores.append(score)
m=min(scores)
l=[]
for i in scores:
    if i!=m:
        l.append(i)      
mm=min(l)
fin=[]
for j in students:
  if mm==j[1]:
    fin.append(j[0])
    
fin.sort()
for k in fin:
    print(k)

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    
    m=0
    for j in student_marks[query_name]:
      m=m+j

    m=m/(len(scores))
    print(f"{m :.2f}")

# %%
#STRINGS

# %%
def split_and_join(line):
    # write your code here
    line=line.split(" ")
    line="-".join(line)
    return line
    

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#
# Complete the 'print_full_name' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    # Write your code here
    print(f"Hello {first} {last}! You just delved into python.")

# %%
def mutate_string(string, position, character):
    
    string= string[:position]+ character + string[position+1:]
    return string

# %%
def swap_case(s):
    return s.swapcase()

# %%
def count_substring(string, sub_string):
    
    count=0

    for i in range(0, len(string)):
        if string[i:i+len(sub_string)]==sub_string:
          count=count+1

    return count

# %%
if __name__ == '__main__':
    s = input()
    
    print (any(map(str.isalnum,s)))
    print (any(map(str.isalpha,s)))
    print (any(map(str.isdigit,s)))
    print (any(map(str.islower,s)))
    print (any(map(str.isupper,s)))

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

n = int(input())

for i in range(n):
    line ="H"+"H"*(2*i) 
    print(line.center(2*n-1,' '))

lspace = int(((2*n-1)-n)/2)

for i in range(n+1):

    line = "H"*n
    print(line.rjust(lspace+n,' ') + line.rjust(n*4,' '))

for i in range(int((n+1)/2)):
    line = "H"*(n*5)
    print(line.rjust(lspace + (n*5),' '))
    
for i in range(n+1):
    line = "H"*n
    print(line.rjust(lspace+n,' ') + line.rjust(n*4,' '))

for i in range(n-1,-1,-1):
    line ="H"+"H"*(2*i) 
    print(" ".rjust(n*4,' ') + line.center(2*n-1,' '))

# %%
def wrap(string, max_width):
    return (textwrap.fill(string,max_width))

# %%
N,M = map(int,input().split())

L=[i for i in range(1,N) if i%2==1]

for j in L:
  print((".|."*j).center(M,"-"))

print("WELCOME".center(M, "-"))

NL=list(reversed(L))

for i in NL:
  print((".|."*i).center(M,"-"))

# %%
def print_formatted(number):
    # your code goes here
    
    m=len(bin(number))-2

    for i in range(1, number+1):
      #decimal=i
      octal=oct(i)[2:]
      hexadecimal=hex(i)[2:].upper()
      binary=bin(i)[2:]
      print(str(i).rjust(m), octal.rjust(m), hexadecimal.rjust(m), binary.rjust(m))

# %%
def print_rangoli(size):
    # your code goes here
    
    letters=' abcdefghijklmnopqrstuvwxyz'

    for i in range(size, 0, -1):
      s=letters[size:i:-1]+letters[i:size+1]
      s='-'.join(s)
      print(s.center((size*4)-3,'-'))

    for i in range(0,size-1):
        s = letters[size:i+2:-1] + letters[i+2:size+1]
        s ='-'.join(s)
        print(s.center((size*4)-3,'-'))

# %%
#SETS

# %%
def average(array):
    # your code goes here
    new=set(array)
    m=sum(new)/len(new)
    return m

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

n, m = map(int,input().split())
l = list(map(int,input().split()))
A = set(map(int,input().split()))
B = set(map(int,input().split()))

count=0

for i in l:
    if i in A:
        count=count+1
    if i in B:
        count=count-1
print(count)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT


n = int(input())
arr1 = set(map(int, input().split()))
m = int(input())
arr2 = set(map(int, input().split()))

i=arr1.intersection(arr2)
u=arr1.union(arr2)

for j in i:
  u.discard(j)

u1=list(u)
u1=sorted(u1)

for j in u1:
  print(j)

# %%
n=int(input())
f = set(map(int, input().split()))
b=int(input())
i = set(map(int, input().split()))

print(len(f.difference(i)))

# %%
n=int(input())
f = set(map(int, input().split()))
b=int(input())
i = set(map(int, input().split()))

print(len(f.symmetric_difference(i)))

# %%
n=int(input())
f = set(map(int, input().split()))
b=int(input())
i = set(map(int, input().split()))

print(len(f.intersection(i)))

# %%
n=int(input())
f = set(map(int, input().split()))
b=int(input())
i = set(map(int, input().split()))

print(len(f.union(i)))

# %%
n = int(input())

A = set(list(map(int, input().split())))

N = int(input())

for i in range(N):
    l = input().split()
    B = set(list(map(int, input().split())))
    if l[0] == 'intersection_update':
        A.intersection_update(B)
    elif l[0] == 'update':
        A.update(B)
    elif l[0] == 'symmetric_difference_update':
        A.symmetric_difference_update(B)
    elif l[0] == 'difference_update':
        A.difference_update(B)

print(sum(A))

# %%
K= int(input())
l = list(map(int,input().split()))

s=set(l)

for i in s:
  l.remove(i)

s1=set(l)

print(*(s-s1))

# %%
N=int(input())

l=[]

for i in range(0,N):
    c=input()
    l.append(c)

s=set(l)

print(len(s))

# %%
T=int(input())

l=[]
for i in range(0,T):
    n=int(input())
    A=set(map(int,input().split()))
    m=int(input())
    B=set(map(int,input().split()))
    C=A.intersection(B)
    if C==A:
        l.append(1)
    else:
        l.append(0)

for i in range(0,T):
  if l[i]==1:
    print("True")
  else:
    print("False")

# %%
#COLLECTIONS

# %%
X=int(input())
s=list(map(int,input().split()))
N=int(input())
c=[]
for i in range(N):
    c.append(list(map(int,input().split())))
sum=0
for i in range(N):
  if c[i][0] in s: 
    sum=sum+c[i][1]
    s.remove(c[i][0])
  

print(sum)

# %%
from collections import defaultdict

n, m=map(int,input().split())

A = defaultdict(list)

for i in range(1,n+1):
    A[input()].append(i)

for i in range(1,m+1):
  b=input()
  if b in A.keys():
    print(*A[b])
  else:
    print(-1)

# %%
from collections import OrderedDict

N=int(input())
ordinary_dictionary = {}

for i in range(N):
    a = input().split()
    obj=" ".join(a[:-1])
    price=int(a[-1])
    ordinary_dictionary[obj] = price + ordinary_dictionary.get(obj, 0)

for obj in ordinary_dictionary:
    print(obj, ordinary_dictionary[obj])

# %%
n=int(input())
l={}

for i in range(n):
    el=input()
    l[el]=l.get(el,0)+1

print(len(l))
for i in l:
    print(l[i],end= ' ')

# %%
from collections import deque

N=int(input())
d = deque()

for i in range (N):
    l=list(input().split())
    if l[0]=='pop':
        d.pop()
    elif l[0]=='popleft':
        d.popleft()
    elif l[0]== 'append':
        d.append(l[1])
    elif l[0]== 'appendleft':
        d.appendleft(l[1])
        
b=list(d)
a=[int(i) for i in b]
print(*a)

# %%
from collections import deque
T=int(input())
d=deque()
ans= "Yes"

for i in range(T):
    n=int(input())
    d=deque(map(int,input().split()))
    while len(d)>=3:
        left=d.popleft()
        right=d.pop()
        #print(d)
        if max(left,right) < max(d[0],d[-1]):
            ans = "No"
            break
    print(ans)

# %%
#DATE AND TIMES

# %%
import datetime
import calendar 
m,d,y= map(int, input().split())

days= ['MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY','SUNDAY']
print (days[calendar.weekday(y,m,d)])

# %%
import math
import os
import random
import re
import sys

# Complete the time_delta function below.
def time_delta(t1, t2):
    from datetime import datetime as dt
    format_time='%a %d %b %Y %H:%M:%S %z'
    t1tm = dt.strptime(t1,format_time)
    t2tm = dt.strptime(t2,format_time)
  
    return str(round(abs((t1tm-t2tm).total_seconds())))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
#EXCEPTIONS

# %%
T=int(input())

for i in range(0,T):
    
    try:
        a, b=map(int, input().split())
        print (a//b)
    except ZeroDivisionError as e:
        print("Error Code:", e)
    except ValueError as e:
        print("Error Code:", e)

# %%
#PYTHON FUNCTIONALS

# %%
cube = lambda x: x**3 # complete the lambda function 

def fibonacci(n):
    f=[]
    a=0
    b=1
    for i in range (n):
        if n==0:
            return f
        if n==1:
            f.append(a)
        else:
            f.append(a)
            c=a+b
            #f.append(c)
            a=b
            b=c
        
    return f
    # return a list of fibonacci numbers

# %%
#BUILT-INS

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())

    for i in range(2):
        sorted_arr=sorted(arr, key=lambda x: x[k])
        
    for i in sorted_arr:
        print(*i)

# %%
string = input()

l=list(string)
low=[]
up=[]
num2=[]
num1=[]


for i in l:
  if 'a'<= i <='z':
    low.append(i)
  elif 'A'<= i <='Z':
    up.append(i)
  elif int(i) % 2 == 1:
    num1.append(i)
  else:
    num2.append(i)

s_low = sorted(low)
s_up = sorted(up)
s_num1 = sorted(num1)
s_num2 = sorted(num2)

print("".join(s_low)+"".join(s_up)+"".join(s_num1)+"".join(s_num2))

# %%
#REGEX AND PARSING CHALLENGES

# %%
import re
T=int(input())

for i in range(T):
    print(True if re.search(r"^[+-]?[0-9]*\.[0-9]+$", input()) else False)

# %%
regex_pattern = r"[,.]"	# Do not delete 'r'.

# %%
import re

s=input()

m = re.search(r"([a-zA-Z0-9])\1+", s)

print(m.group()[0] if m else -1)

# %%
#XML

# %%
score=0

def get_attr_number(node):
    # your code goes here
    global score
    score += len(node.attrib) 
    for child in node:
        get_attr_number(child)
    return score

# %%
maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    if (level == maxdepth):
        maxdepth += 1
    for child in elem:
        depth(child, level + 1)

# %%
#CLOSURES AND DECORATIONS

# %%
def wrapper(f):
    def fun(l):
        # complete the function
        
        f(['+91 ' + i[-10:-5] + ' ' + i[-5:] for i in l])

    return fun

# %%
def person_lister(f):
    def inner(people):
        # complete the function
        
        people.sort(key=lambda x: int(x[2]))
        return [f(person) for person in people]
    return inner

# %%
#NUMPY

# %%
def arrays(arr):
    # complete this function
    # use numpy.array
    a = list(reversed(arr))
    b=numpy.array(a,float)
    return b

# %%
import numpy

l=list(map(int,input().split()))
x=numpy.array(l)

x.shape=(3,3)

print (x)

# %%
import numpy

N,M=map(int,input().split())
l=[]
for i in range(N):
    l.append(list(map(int,input().split())))
    
t = numpy.array(l)
print(numpy.transpose(t))
print(t.flatten())

# %%
import numpy

N, M, P=map(int, input().split())

m1=[]
m2=[]

for i in range(N):
    m1.append(list(map(int, input().split())))
    
for i in range(M):
    m2.append(list(map(int, input().split())))

arr1=numpy.array(m1)
arr2=numpy.array(m2)

print (numpy.concatenate((arr1, arr2), axis = 0))

# %%
import numpy

size=list(map(int, input().split()))

[print (numpy.zeros((size), dtype = numpy.int))]

[print (numpy.ones((size), dtype = numpy.int))]

# %%
import numpy

numpy.set_printoptions(legacy='1.13')

N, M=map(int, input().split())

print (numpy.eye(N, M))

# %%
import numpy

N,M=map(int, input().split())

m1=[]
m2=[]

for i in range(N):
    m1.append(list(map(int,input().split())))

for i in range(N):
    m2.append(list(map(int,input().split())))
    
A=numpy.array(m1)
B=numpy.array(m2)

# %%
import numpy

numpy.set_printoptions(legacy='1.13')

A=numpy.array(list(map(float,input().split())))

print (numpy.floor(A))

print (numpy.ceil(A))

print (numpy.rint(A))

# %%
import numpy

N, M=map(int,input().split())
m=[]
for i in range(N):
    m.append(list(map(int,input().split())))
    
    
B=numpy.sum(m, axis = 0)

print (numpy.prod(B, axis = 0))

# %%
import numpy

N,M=map(int, input().split())

m1=[]

for i in range(N):
    m1.append(list(map(int,input().split())))

arr=numpy.array(m1)

b=numpy.min(arr, axis = 1)

print (numpy.max(b))

# %%
import numpy

N,M=map(int, input().split())

m1=[]

for i in range(N):
    m1.append(list(map(int,input().split())))

arr=numpy.array(m1)

print(numpy.mean(arr, axis = 1))
    
print (numpy.var(arr, axis = 0))   
    
print (round(numpy.std(arr),11))

# %%
import numpy

N=int(input())

m1=[]
m2=[]

for i in range(N):
    m1.append(list(map(int,input().split())))

for i in range(N):
    m2.append(list(map(int,input().split())))
    
    
    
arr1=numpy.array(m1)
arr2=numpy.array(m2)
p=[]

for i in range(N):
    for j in range(N):
        c=numpy.dot(arr1[i,0:N+1], arr2[0:N+1,j])
        p.append(c)
    
a=numpy.array(p)
a1 = numpy.reshape(a, (N, N))
print(a1)

# %%
#PROBLEM 2

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    # Write your code here
    
    m=max(candles)
    return(candles.count(m))
    
    
    
    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    # Write your code here
    
    if v1-v2==0 & x1!=x2:
        return "NO"
        
    n=(x2-x1)/(v1-v2)
    m=int(n)
    
    if n==m & m>=0:
        return "YES"
    else:
        return "NO"
        
    
    
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    # Write your code here
    l=5/3
    c=0
    for d in range(1,n+1):
        s=3*l
        l=int(s/2)
        c=l+c
        
    return c
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    # Write your code here
    
    for i in range(n-1,0,-1):
        if arr[i]<arr[i-1]:
            a=arr[i]
            arr[i]=arr[i-1]
            print(*arr)
            arr[i-1]=a
            
    print(*arr)
            
    

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    # Write your code here
    
    for i in range(1,n):
        for j in range(0,i):
            if arr[i]<arr[j]:
                a=arr[i]
                arr[i]=arr[j]
                arr[j]=a
        print(*arr)
            
    
    
    
    
    

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)
